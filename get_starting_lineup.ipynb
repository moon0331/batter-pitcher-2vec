# %%
import statsapi
import pybaseball
from pprint import pprint
import pandas as pd

# %%
gamepk = 633611

print(pybaseball.statcast_single_game(gamepk))

data = statsapi.get("game", {"gamePk": gamepk})
data.keys()
# Out:
#     pitch_type  game_date  release_speed  release_pos_x  release_pos_z  \
# 207         FF 2021-06-20           94.7          -2.11           5.67
# 211         SL 2021-06-20           79.5          -2.05           5.80
# 217         SL 2021-06-20           80.0          -1.88           5.75
# 228         SL 2021-06-20           81.9          -2.08           5.81
# 229         SL 2021-06-20           80.1          -2.06           5.79
# ..         ...        ...            ...            ...            ...
# 241         FF 2021-06-20           93.5           0.76           6.30
# 251         CH 2021-06-20           79.4           0.68           6.42
# 260         CH 2021-06-20           81.0           0.85           6.32
# 261         FF 2021-06-20           92.4           0.81           6.32
# 274         FF 2021-06-20           91.8           0.80           6.29
#
#            player_name  batter  pitcher     events      description  ...  \
# ...

# %%
data
# Out:
# {'copyright': 'Copyright 2022 MLB Advanced Media, L.P.  Use of any content on this page acknowledges agreement to the terms posted here http://gdx.mlb.com/components/copyright.txt',
#  'gamePk': 633611,
#  'link': '/api/v1.1/game/633611/feed/live',
#  'metaData': {'wait': 10,
#   'timeStamp': '20210620_225840',
#   'gameEvents': ['strikeout', 'game_finished'],
#   'logicalEvents': ['midInning',
#    'countChange',
#    'count13',
#    'gameStateChangeToGameOver']},
#  'gameData': {'game': {'pk': 633611,
#    'type': 'R',
#    'doubleHeader': 'N',
#    'id': '2021/06/20/phimlb-sfnmlb-1',
#    'gamedayType': 'P',
#    'tiebreaker': 'N',
#    'gameNumber': 1,
#    'calendarEventID': '14-633611-2021-06-20',
#    'season': '2021',
#    'seasonDisplay': '2021'},
#   'datetime': {'dateTime': '2021-06-20T20:05:00Z',
#    'originalDate': '2021-06-20',
#    'officialDate': '2021-06-20',
#    'dayNight': 'day',
#    'time': '1:05',
#    'ampm': 'PM'},
# ...

# %%
lineup = data['liveData']['boxscore']['teams']['away']['batters']
print(list(lineup))
# Out:
# [663897, 656555, 571735, 592663, 547180, 608671, 457705, 675921, 593576, 665561, 664761, 663837, 591720, 621107, 546318]

# %%
db = pybaseball.playerid_reverse_lookup(lineup)
db
# Out:
#     name_last name_first  key_mlbam key_retro  key_bbref  key_fangraphs  \
# 0        bohm       alec     664761  bohma001   bohmal01          21618
# 1       eflin       zach     621107  efliz001  eflinza01          13774
# 2        hale      david     571735  haled001   haleda02           9756
# 3      harper      bryce     547180  harpb003  harpebr03          11579
# 4     herrera     odubel     546318  herro001  herreod01          11476
# 5     hoskins       rhys     656555  hoskr001  hoskirh01          16472
# 6      howard    spencer     675921  howas003  howarsp01          23252
# 7   jankowski     travis     608671  jankt001  jankotr01          13768
# 8     marchan     rafael     665561  marcr001  marchra01          21646
# 9   mccutchen     andrew     457705  mccua001  mccutan01           9847
# 10      neris     hector     593576  nerih001  nerishe01          11804
# 11   realmuto      j. t.     592663  realj001  realmjt01          11739
# ...

# %%
for player_id in lineup:
    # print full name
    print(statsapi.get("person", {"personId": player_id})['people'][0]['fullName'])
# Out:
# Luke Williams
# Rhys Hoskins
# David Hale
# J.T. Realmuto
# Bryce Harper
# Travis Jankowski
# Andrew McCutchen
# Spencer Howard
# Hector Neris
# Rafael Marchan
# Alec Bohm
# Matt Vierling
# Ronald Torreyes
# Zach Eflin
# Odubel Herrera
